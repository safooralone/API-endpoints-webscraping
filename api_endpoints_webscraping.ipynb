# %%
import requests
import json
import pandas as pd
url="https://api.afl.com.au/statspro/playersStats/seasons/CD_S2025014?includeBenchmarks=false"

# %%
import requests

url = "https://api.afl.com.au/statspro/playersStats/seasons/CD_S2025014?includeBenchmarks=false"

payload = {}
headers = {
  'accept': '*/*',
  'accept-language': 'en-US,en;q=0.9',
  'if-none-match': 'W/"dcfa3726d372e3fc5c574dad3ea09803"',
  'origin': 'https://www.afl.com.au',
  'priority': 'u=1, i',
  'referer': 'https://www.afl.com.au/',
  'sec-ch-ua': '"Chromium";v="140", "Not=A?Brand";v="24", "Google Chrome";v="140"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-site',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/140.0.0.0 Safari/537.36',
  'x-media-mis-token': '6adc66ae74fe0d877247fac846f0cba7'
}

response = requests.request("GET", url, headers=headers)

data=response.json()
print(data.keys())
if "players" in data:
    df=pd.json_normalize(data["players"])
    print(df.head(10))
# Out:
# dict_keys(['search', 'totalResults', 'players'])
#       playerId  gamesPlayed playerDetails.givenName playerDetails.surname  \
# 0  CD_I1000061          1.0                  Callum         Coleman-Jones
# 1  CD_I1000068          1.0                   Chris               Burgess
# 2  CD_I1000072         25.0                    John                 Noble
# 3  CD_I1000223         23.0                    Liam                 Baker
# 4  CD_I1000860         16.0                  Lachie               Schultz
# 5  CD_I1000864         23.0                 Lachlan               Bramble
# 6  CD_I1000887          8.0                   Mitch                 Lewis
# 7  CD_I1000932          1.0                     Tom                Doedee
# 8  CD_I1000937         20.0                    Jack                 Henry
# 9  CD_I1000953         12.0                   Harry                 McKay
#
#    playerDetails.age  playerDetails.heightCm  playerDetails.weightKg  \
# ...

# %%
with open("players_data.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False,indent=4)
